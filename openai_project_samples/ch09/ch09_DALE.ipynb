# %%
from openai import OpenAI

# %%
client = OpenAI(api_key="yourServiceKey")

# %%
response = client.images.generate(
  model="dall-e-3",
  prompt="무엇이든 물어보세요. 귀엽고 친절한 첨단 고객센터 AI 로봇이에요. 이미지의 배경은 흰색입니다.",
  size="1024x1024",
  quality="standard",
  n=1
)

print(response)
# Out:
# ImagesResponse(created=1754743039, background=None, data=[Image(b64_json=None, revised_prompt="Create an image of an adorable and friendly advanced customer service AI robot. The robot has a modern design emphasizing both cuteness and efficiency. It has a bright, welcoming expression on its 'face'. It is posed in such a way that suggests readiness and approachability. The background of the image is a clean, crisp white.", url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-IuRkX4c5bVNMUrHNwWWbsE9P/user-ElPXsMQNFmCgApZNCzl9XfnP/img-PEM5vHobU5ianQWylFqAqIYo.png?st=2025-08-09T11%3A37%3A19Z&se=2025-08-09T13%3A37%3A19Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=f1dafa11-a0c2-4092-91d4-10981fbda051&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-08-08T20%3A18%3A02Z&ske=2025-08-09T20%3A18%3A02Z&sks=b&skv=2024-08-04&sig=/ufMeLbk/vzvNifoQJP5wosQn6Zlhm%2BgT7Fy%2BRNGmF8%3D')], output_format=None, quality=None, size=None, usage=None)

# %%
response = client.images.generate(
  model="dall-e-3",
  prompt="무엇이든 물어보세요. 귀엽고 친절한 첨단 고객센터 AI 로봇이에요. 이미지의 배경은 흰색입니다.",
  size="1024x1024",
  quality="hd",
  n=1
)

image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-IuRkX4c5bVNMUrHNwWWbsE9P/user-ElPXsMQNFmCgApZNCzl9XfnP/img-kw5ib05nHiSuOr2c50IzbLK5.png?st=2025-08-09T11%3A41%3A07Z&se=2025-08-09T13%3A41%3A07Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=f1dafa11-a0c2-4092-91d4-10981fbda051&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-08-08T19%3A28%3A34Z&ske=2025-08-09T19%3A28%3A34Z&sks=b&skv=2024-08-04&sig=Y4SnS36auhdT1lzAnpiRs2Y9JINLZ4OWmVRX2fQc014%3D

# %%
response = client.images.generate(
  model="dall-e-3",
  prompt="반고흐 그림체로 하얀색 강아지가 숲에서 다른 동물들한테 열심히 설명하는 장면을 그려줘",
  size="1024x1024",
  quality="standard",
  n=1,
  response_format='b64_json'
)

print(response)
# Out:
# ImagesResponse(created=1754744287, background=None, data=[Image(b64_json='...', revised_prompt='Create an image in the style characterized by bold brushstrokes, dramatic swirls, and vivid color contrast associated with post-Impressionist era, similar to the style of Van Gogh. The scene features a white dog, standing in the midst of a forest, passionately explaining something to the other animals around it.', url=None)], output_format=None, quality=None, size=None, usage=None)

# %%
from PIL import Image
import io
import base64
from IPython.display import display

image_data = base64.b64decode(response.data[0].b64_json)
image = Image.open(io.BytesIO(image_data))
image.save("image.png")
display(image)
